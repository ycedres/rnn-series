# %% [markdown]
# # NREL - Offshore WA OR - turbine: 25915
#
# ## Predicción: h = 1 / H = 24
#
# ## Neural Network - LSTM

# %%
# %matplotlib inline
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# import RenewAI
sys.path.append('/Users/tmorales/tmp/RNN-windPower/src')
from pre_process.split_ml_ts import dataframe_split

# %%
exp_path = '/Users/tmorales/tmp/experiments/NREL/Offshore_WA_OR/turbine_25915'
experiment_name = 'nn-lstm-weights-normal'
directory = os.path.join(exp_path, experiment_name)
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# ## Load file

# %%
path = '/Users/tmorales/tmp/RNN-windPower/database/wind_farms/Offshore_WA_OR/Offshore_WA_OR_features'

# %%
os.chdir(path)
files = [file for file in glob.glob('Offshore_WA_OR_features_*.csv')]
files
# Out:
# ['Offshore_WA_OR_features_h_01.csv',
#  'Offshore_WA_OR_features_h_02.csv',
#  'Offshore_WA_OR_features_h_03.csv',
#  'Offshore_WA_OR_features_h_04.csv',
#  'Offshore_WA_OR_features_h_05.csv',
#  'Offshore_WA_OR_features_h_06.csv',
#  'Offshore_WA_OR_features_h_07.csv',
#  'Offshore_WA_OR_features_h_08.csv',
#  'Offshore_WA_OR_features_h_09.csv',
#  'Offshore_WA_OR_features_h_10.csv',
#  'Offshore_WA_OR_features_h_11.csv',
#  'Offshore_WA_OR_features_h_12.csv',
#  'Offshore_WA_OR_features_h_13.csv',
#  'Offshore_WA_OR_features_h_14.csv',
#  'Offshore_WA_OR_features_h_15.csv',
#  'Offshore_WA_OR_features_h_16.csv',
#  'Offshore_WA_OR_features_h_17.csv',
#  'Offshore_WA_OR_features_h_18.csv',
#  'Offshore_WA_OR_features_h_19.csv',
#  'Offshore_WA_OR_features_h_20.csv',
#  'Offshore_WA_OR_features_h_21.csv',
#  'Offshore_WA_OR_features_h_22.csv',
#  'Offshore_WA_OR_features_h_23.csv',
#  'Offshore_WA_OR_features_h_24.csv']

# %% [markdown]
# ## Paso 1: only one h-step

# %%
h1 = files[0]

# %%
# create directory for each horizont (each horizon is a regressor)
horizont = 1
directory_by_horizont = os.path.join(exp_path, 
                                     experiment_name,
                                     'model_saved_h={0:03d}'.format(horizont))
if not os.path.exists(directory_by_horizont):
    os.makedirs(directory_by_horizont)

# %%
# load file
df_h1 = pd.read_csv(files[0], delimiter=';', index_col=0)
df_h1.head(4)
# Out:
#                       f_0   f_1   f_2   f_3   f_4   f_5  target_h1
# target_date
# 2004-01-01 06:00:00  6.96  5.28  5.32  4.93  4.05  3.95       4.19
# 2004-01-01 07:00:00  5.28  5.32  4.93  4.05  3.95  4.19       4.89
# 2004-01-01 08:00:00  5.32  4.93  4.05  3.95  4.19  4.89       5.16
# 2004-01-01 09:00:00  4.93  4.05  3.95  4.19  4.89  5.16       5.01

# %%
# select the best model for h=1

# split the dataset in train, val and test
data = dataframe_split(df_h1)
train_set = data['train_set']
validation_set = data['validation_set']
test_set = data['test_set']

# %%
# features and target columns
features_columns = train_set.columns[1:-1]
target_column = train_set.columns[-1:]

# %%
# select the values of features and target columns.
features_train_set = train_set[features_columns]
target_train_set = train_set[target_column]
features_validation_set = validation_set[features_columns]
target_validation_set = validation_set[target_column]
features_test_set = test_set[features_columns]
target_test_set = test_set[target_column]

# %%
# select values
x_train = features_train_set.values.astype('float32')
y_train = target_train_set.values
x_val = features_validation_set.values.astype('float32')
y_val = target_validation_set.values
y_test = target_test_set.values

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(15,10))

min_xval = np.array([y_train.min(), y_val.min(), y_test.min()]).min()
max_val = np.array([y_train.max(), y_val.max(), y_test.max()]).max()
ax1.hist(y_train, bins=40, color='r', label='train')
ax1.set_xlim([min_xval, max_val])
ax1.legend()
ax2.hist(y_val, bins=40, color='b', label='validation')
ax2.set_xlim([min_xval, max_val])
ax2.legend()
ax3.hist(y_test, bins=40, color='g', label='test')
ax3.set_xlim([min_xval, max_val])
ax3.legend()
ax4.hist(y_train, bins=40, color='r', label='train')
ax4.hist(y_val, bins=40, color='b', label='validation')
#ax4.hist(y_test, bins=40, color='g', label='test')
ax4.set_xlim([min_xval, max_val])
ax4.legend();

# %%
f = plt.figure(figsize = (15, 7))
max_train_test = np.array([y_train.max(), y_val.max()]).max()
plt.axhline(y=max_train_test, color='black', label='train and validation max value ')
plt.scatter(x = range(len(y_train)),
            y = y_train, color='r', label='train')
plt.scatter(x = range(len(y_val)),
            y = y_val, color='b', label='validation' )
plt.scatter(x = range(len(y_test)),
            y = y_test, color='g', label='test' )
plt.legend(fontsize=15)
plt.ylabel(r'Wind velocity ($\frac{m}{sg}$)', fontsize=20)
plt.xlabel(r'Number of examples', fontsize=20);

# %%
print('N of examples: {0}'.format(x_train.shape))
# Out:
# N of examples: (16830, 5)

# %%
x_train.max()
# Out:
# 22.25

# %% [markdown]
# ## Paso 2: Model defenition

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.optimizers import Adam
from keras.utils import plot_model
from keras.callbacks import TensorBoard
# Out:
# /Users/tmorales/interpreters/anaconda3/envs/p3tf1/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# reshape the data for training LSTM
print(x_train.shape)
x_train_lstm = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
print(x_train_lstm.shape)

x_val_lstm = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
#x_test_lstm = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# Out:
# (16830, 5)
# (16830, 5, 1)

# %%
def create_model(time_step, feature_by_timestep,
                 plot_title):
    # Input layer
    input = Input((time_step,
                   feature_by_timestep),
                   dtype='float32',
                   name='input-layer')
    normalize_input = BatchNormalization(name='normalize-input')(input)
    # RNN - LSTM
    x = LSTM(10, 
             kernel_initializer='normal',
             name='lstm-layer')(normalize_input)
    # Fully-connect
    x = Dense(10,
              kernel_initializer='normal',
              activation='relu',
              name='hidden-layer-1')(x)
    x = Dense(5, 
              kernel_initializer='normal', 
              activation='relu',
              name='hidden-layer-2')(x)
    x = Dense(3,
              kernel_initializer='normal',
              activation='relu',
              name='hidden-layer-3')(x)
    #x = Dropout(rate=0.2)(x)
    output = Dense(1, 
                   kernel_initializer='normal', 
                   activation='linear',
                   name='output-layer')(x)
    # Model
    model = Model(inputs=input, outputs=output)
    model.summary()
    
    plot_model(model,
               to_file='{0}.png'.format(plot_title),
               show_shapes=True,
               show_layer_names=True,
               rankdir='LR')
    
    return model

# %%
def fit_model(model, x_train, y_train, x_val, y_val, exp_path,
              epochs=100, batch_size=50, lr=0.001):
    
    tensorboard = TensorBoard(log_dir=os.path.join(exp_path, 'graph'),
                              histogram_freq=1)
    
    opt = Adam(lr=lr)
    model.compile(loss='mean_squared_error',
                  optimizer=opt,
                  metrics=['mae'])
    
    history = model.fit(x_train,
                        y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_val, y_val),
                        callbacks=[tensorboard])
    
    return model, history

# %%
model = create_model(5, 1, plot_title='lstm')
model, history = fit_model(model, x_train_lstm, y_train, x_val_lstm, y_val,
                           exp_path=directory, batch_size=1024, epochs=100)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input-layer (InputLayer)     (None, 5, 1)              0
# _________________________________________________________________
# normalize-input (BatchNormal (None, 5, 1)              4
# _________________________________________________________________
# lstm-layer (LSTM)            (None, 10)                480
# _________________________________________________________________
# hidden-layer-1 (Dense)       (None, 10)                110
# _________________________________________________________________
# hidden-layer-2 (Dense)       (None, 5)                 55
# _________________________________________________________________
# hidden-layer-3 (Dense)       (None, 3)                 18
# _________________________________________________________________
# output-layer (Dense)         (None, 1)                 4
# =================================================================
# Total params: 671
# Trainable params: 669
# Non-trainable params: 2
# _________________________________________________________________
# Train on 16830 samples, validate on 4208 samples
# Epoch 1/100
# 16830/16830 [==============================] - 1s 87us/step - loss: 49.3994 - mean_absolute_error: 6.1137 - val_loss: 49.2192 - val_mean_absolute_error: 6.1115
# Epoch 2/100
# 16830/16830 [==============================] - 1s 73us/step - loss: 49.1694 - mean_absolute_error: 6.0949 - val_loss: 48.9759 - val_mean_absolute_error: 6.0916
# Epoch 3/100
# 16830/16830 [==============================] - 1s 72us/step - loss: 48.9167 - mean_absolute_error: 6.0743 - val_loss: 48.6901 - val_mean_absolute_error: 6.0685
# Epoch 4/100
# 16830/16830 [==============================] - 1s 72us/step - loss: 48.6149 - mean_absolute_error: 6.0501 - val_loss: 48.2967 - val_mean_absolute_error: 6.0377
# Epoch 5/100
# 16830/16830 [==============================] - 1s 71us/step - loss: 48.1877 - mean_absolute_error: 6.0175 - val_loss: 47.6416 - val_mean_absolute_error: 5.9881
# Epoch 6/100
# 16830/16830 [==============================] - 1s 73us/step - loss: 47.4485 - mean_absolute_error: 5.9641 - val_loss: 46.4324 - val_mean_absolute_error: 5.8974
# Epoch 7/100
# 16830/16830 [==============================] - 1s 71us/step - loss: 46.0378 - mean_absolute_error: 5.8633 - val_loss: 44.2619 - val_mean_absolute_error: 5.7289
# Epoch 8/100
# 16830/16830 [==============================] - 1s 67us/step - loss: 43.4290 - mean_absolute_error: 5.6637 - val_loss: 40.7145 - val_mean_absolute_error: 5.4269
# Epoch 9/100
# 16830/16830 [==============================] - 1s 67us/step - loss: 39.0635 - mean_absolute_error: 5.2807 - val_loss: 35.5743 - val_mean_absolute_error: 4.9372
# Epoch 10/100
# 16830/16830 [==============================] - 1s 67us/step - loss: 33.0911 - mean_absolute_error: 4.6842 - val_loss: 29.2876 - val_mean_absolute_error: 4.3047
# Epoch 11/100
# 16830/16830 [==============================] - 1s 64us/step - loss: 26.4630 - mean_absolute_error: 3.9999 - val_loss: 22.7717 - val_mean_absolute_error: 3.6596
# Epoch 12/100
# 16830/16830 [==============================] - 1s 63us/step - loss: 20.1763 - mean_absolute_error: 3.3573 - val_loss: 17.0704 - val_mean_absolute_error: 3.0797
# Epoch 13/100
# 16830/16830 [==============================] - 1s 64us/step - loss: 15.1232 - mean_absolute_error: 2.8449 - val_loss: 12.9477 - val_mean_absolute_error: 2.6438
# Epoch 14/100
# 16830/16830 [==============================] - 1s 70us/step - loss: 11.4017 - mean_absolute_error: 2.4184 - val_loss: 9.7360 - val_mean_absolute_error: 2.2112
# Epoch 15/100
# 16830/16830 [==============================] - 1s 72us/step - loss: 8.5917 - mean_absolute_error: 2.0053 - val_loss: 7.4864 - val_mean_absolute_error: 1.8791
# Epoch 16/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 6.8473 - mean_absolute_error: 1.7724 - val_loss: 6.1147 - val_mean_absolute_error: 1.7033
# Epoch 17/100
# 16830/16830 [==============================] - 1s 73us/step - loss: 5.6403 - mean_absolute_error: 1.6039 - val_loss: 5.0705 - val_mean_absolute_error: 1.5441
# Epoch 18/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 4.7575 - mean_absolute_error: 1.4655 - val_loss: 4.3093 - val_mean_absolute_error: 1.4240
# Epoch 19/100
# 16830/16830 [==============================] - 1s 81us/step - loss: 4.1257 - mean_absolute_error: 1.3732 - val_loss: 3.7689 - val_mean_absolute_error: 1.3447
# Epoch 20/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 3.6460 - mean_absolute_error: 1.2958 - val_loss: 3.3409 - val_mean_absolute_error: 1.2723
# Epoch 21/100
# 16830/16830 [==============================] - 1s 74us/step - loss: 3.2741 - mean_absolute_error: 1.2392 - val_loss: 3.0218 - val_mean_absolute_error: 1.2197
# Epoch 22/100
# 16830/16830 [==============================] - 1s 79us/step - loss: 2.9888 - mean_absolute_error: 1.1953 - val_loss: 2.7559 - val_mean_absolute_error: 1.1709
# Epoch 23/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 2.7732 - mean_absolute_error: 1.1579 - val_loss: 2.5583 - val_mean_absolute_error: 1.1387
# Epoch 24/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 2.5681 - mean_absolute_error: 1.1187 - val_loss: 2.3800 - val_mean_absolute_error: 1.0988
# Epoch 25/100
# 16830/16830 [==============================] - 1s 79us/step - loss: 2.4273 - mean_absolute_error: 1.0976 - val_loss: 2.2364 - val_mean_absolute_error: 1.0684
# Epoch 26/100
# 16830/16830 [==============================] - 1s 84us/step - loss: 2.2861 - mean_absolute_error: 1.0648 - val_loss: 2.1170 - val_mean_absolute_error: 1.0421
# Epoch 27/100
# 16830/16830 [==============================] - 1s 79us/step - loss: 2.1658 - mean_absolute_error: 1.0428 - val_loss: 2.0111 - val_mean_absolute_error: 1.0178
# Epoch 28/100
# 16830/16830 [==============================] - 1s 82us/step - loss: 2.0541 - mean_absolute_error: 1.0132 - val_loss: 1.9231 - val_mean_absolute_error: 0.9989
# Epoch 29/100
# 16830/16830 [==============================] - 1s 78us/step - loss: 1.9597 - mean_absolute_error: 0.9960 - val_loss: 1.8358 - val_mean_absolute_error: 0.9758
# Epoch 30/100
# 16830/16830 [==============================] - 1s 81us/step - loss: 1.8717 - mean_absolute_error: 0.9717 - val_loss: 1.7612 - val_mean_absolute_error: 0.9565
# Epoch 31/100
# 16830/16830 [==============================] - 1s 85us/step - loss: 1.7901 - mean_absolute_error: 0.9529 - val_loss: 1.6914 - val_mean_absolute_error: 0.9378
# Epoch 32/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 1.7255 - mean_absolute_error: 0.9371 - val_loss: 1.6253 - val_mean_absolute_error: 0.9168
# Epoch 33/100
# 16830/16830 [==============================] - 1s 86us/step - loss: 1.6636 - mean_absolute_error: 0.9185 - val_loss: 1.5705 - val_mean_absolute_error: 0.9023
# Epoch 34/100
# 16830/16830 [==============================] - 1s 85us/step - loss: 1.6041 - mean_absolute_error: 0.9029 - val_loss: 1.5168 - val_mean_absolute_error: 0.8855
# Epoch 35/100
# 16830/16830 [==============================] - 1s 79us/step - loss: 1.5470 - mean_absolute_error: 0.8868 - val_loss: 1.4693 - val_mean_absolute_error: 0.8705
# Epoch 36/100
# 16830/16830 [==============================] - 1s 86us/step - loss: 1.5025 - mean_absolute_error: 0.8729 - val_loss: 1.4273 - val_mean_absolute_error: 0.8574
# Epoch 37/100
# 16830/16830 [==============================] - 1s 83us/step - loss: 1.4601 - mean_absolute_error: 0.8592 - val_loss: 1.3877 - val_mean_absolute_error: 0.8441
# Epoch 38/100
# 16830/16830 [==============================] - 1s 78us/step - loss: 1.4055 - mean_absolute_error: 0.8452 - val_loss: 1.3502 - val_mean_absolute_error: 0.8316
# Epoch 39/100
# 16830/16830 [==============================] - 1s 81us/step - loss: 1.3763 - mean_absolute_error: 0.8331 - val_loss: 1.3172 - val_mean_absolute_error: 0.8188
# Epoch 40/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.3396 - mean_absolute_error: 0.8229 - val_loss: 1.2868 - val_mean_absolute_error: 0.8084
# Epoch 41/100
# 16830/16830 [==============================] - 1s 74us/step - loss: 1.3137 - mean_absolute_error: 0.8143 - val_loss: 1.2614 - val_mean_absolute_error: 0.7993
# Epoch 42/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.2836 - mean_absolute_error: 0.8029 - val_loss: 1.2412 - val_mean_absolute_error: 0.7915
# Epoch 43/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.2464 - mean_absolute_error: 0.7898 - val_loss: 1.2127 - val_mean_absolute_error: 0.7806
# Epoch 44/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 1.2340 - mean_absolute_error: 0.7858 - val_loss: 1.1925 - val_mean_absolute_error: 0.7737
# Epoch 45/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.2008 - mean_absolute_error: 0.7728 - val_loss: 1.1734 - val_mean_absolute_error: 0.7647
# Epoch 46/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.1811 - mean_absolute_error: 0.7633 - val_loss: 1.1557 - val_mean_absolute_error: 0.7581
# Epoch 47/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.1649 - mean_absolute_error: 0.7579 - val_loss: 1.1397 - val_mean_absolute_error: 0.7514
# Epoch 48/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.1408 - mean_absolute_error: 0.7487 - val_loss: 1.1255 - val_mean_absolute_error: 0.7454
# Epoch 49/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.1383 - mean_absolute_error: 0.7493 - val_loss: 1.1153 - val_mean_absolute_error: 0.7398
# Epoch 50/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.1280 - mean_absolute_error: 0.7463 - val_loss: 1.0998 - val_mean_absolute_error: 0.7353
# Epoch 51/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 1.1076 - mean_absolute_error: 0.7389 - val_loss: 1.0888 - val_mean_absolute_error: 0.7295
# Epoch 52/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.0900 - mean_absolute_error: 0.7305 - val_loss: 1.0775 - val_mean_absolute_error: 0.7239
# Epoch 53/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 1.0751 - mean_absolute_error: 0.7241 - val_loss: 1.0681 - val_mean_absolute_error: 0.7199
# Epoch 54/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.0645 - mean_absolute_error: 0.7197 - val_loss: 1.0574 - val_mean_absolute_error: 0.7162
# Epoch 55/100
# 16830/16830 [==============================] - 1s 78us/step - loss: 1.0551 - mean_absolute_error: 0.7181 - val_loss: 1.0542 - val_mean_absolute_error: 0.7129
# Epoch 56/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 1.0453 - mean_absolute_error: 0.7138 - val_loss: 1.0397 - val_mean_absolute_error: 0.7082
# Epoch 57/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 1.0387 - mean_absolute_error: 0.7106 - val_loss: 1.0326 - val_mean_absolute_error: 0.7036
# Epoch 58/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 1.0265 - mean_absolute_error: 0.7052 - val_loss: 1.0269 - val_mean_absolute_error: 0.7012
# Epoch 59/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.0312 - mean_absolute_error: 0.7084 - val_loss: 1.0184 - val_mean_absolute_error: 0.7012
# Epoch 60/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.0422 - mean_absolute_error: 0.7138 - val_loss: 1.0249 - val_mean_absolute_error: 0.6986
# Epoch 61/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 1.0128 - mean_absolute_error: 0.7004 - val_loss: 1.0038 - val_mean_absolute_error: 0.6926
# Epoch 62/100
# 16830/16830 [==============================] - 1s 74us/step - loss: 1.0051 - mean_absolute_error: 0.6957 - val_loss: 0.9981 - val_mean_absolute_error: 0.6878
# Epoch 63/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 0.9931 - mean_absolute_error: 0.6911 - val_loss: 0.9916 - val_mean_absolute_error: 0.6860
# Epoch 64/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9836 - mean_absolute_error: 0.6865 - val_loss: 0.9893 - val_mean_absolute_error: 0.6835
# Epoch 65/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9792 - mean_absolute_error: 0.6860 - val_loss: 0.9803 - val_mean_absolute_error: 0.6807
# Epoch 66/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9809 - mean_absolute_error: 0.6875 - val_loss: 0.9776 - val_mean_absolute_error: 0.6788
# Epoch 67/100
# 16830/16830 [==============================] - 1s 78us/step - loss: 0.9655 - mean_absolute_error: 0.6793 - val_loss: 0.9707 - val_mean_absolute_error: 0.6755
# Epoch 68/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 0.9626 - mean_absolute_error: 0.6783 - val_loss: 0.9658 - val_mean_absolute_error: 0.6726
# Epoch 69/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 0.9667 - mean_absolute_error: 0.6804 - val_loss: 0.9612 - val_mean_absolute_error: 0.6706
# Epoch 70/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9760 - mean_absolute_error: 0.6841 - val_loss: 0.9585 - val_mean_absolute_error: 0.6706
# Epoch 71/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9562 - mean_absolute_error: 0.6755 - val_loss: 0.9554 - val_mean_absolute_error: 0.6670
# Epoch 72/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 0.9557 - mean_absolute_error: 0.6768 - val_loss: 0.9486 - val_mean_absolute_error: 0.6651
# Epoch 73/100
# 16830/16830 [==============================] - 1s 75us/step - loss: 0.9405 - mean_absolute_error: 0.6671 - val_loss: 0.9461 - val_mean_absolute_error: 0.6638
# Epoch 74/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 0.9322 - mean_absolute_error: 0.6645 - val_loss: 0.9409 - val_mean_absolute_error: 0.6610
# Epoch 75/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9422 - mean_absolute_error: 0.6699 - val_loss: 0.9376 - val_mean_absolute_error: 0.6596
# Epoch 76/100
# 16830/16830 [==============================] - 1s 78us/step - loss: 0.9308 - mean_absolute_error: 0.6639 - val_loss: 0.9396 - val_mean_absolute_error: 0.6588
# Epoch 77/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9358 - mean_absolute_error: 0.6656 - val_loss: 0.9314 - val_mean_absolute_error: 0.6577
# Epoch 78/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9301 - mean_absolute_error: 0.6623 - val_loss: 0.9289 - val_mean_absolute_error: 0.6536
# Epoch 79/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9183 - mean_absolute_error: 0.6574 - val_loss: 0.9248 - val_mean_absolute_error: 0.6521
# Epoch 80/100
# 16830/16830 [==============================] - 1s 77us/step - loss: 0.9341 - mean_absolute_error: 0.6668 - val_loss: 0.9213 - val_mean_absolute_error: 0.6514
# Epoch 81/100
# 16830/16830 [==============================] - 1s 78us/step - loss: 0.9295 - mean_absolute_error: 0.6641 - val_loss: 0.9198 - val_mean_absolute_error: 0.6490
# Epoch 82/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9218 - mean_absolute_error: 0.6581 - val_loss: 0.9173 - val_mean_absolute_error: 0.6478
# Epoch 83/100
# 16830/16830 [==============================] - 1s 76us/step - loss: 0.9159 - mean_absolute_error: 0.6544 - val_loss: 0.9146 - val_mean_absolute_error: 0.6465
# Epoch 84/100
# 16830/16830 [==============================] - 1s 80us/step - loss: 0.9144 - mean_absolute_error: 0.6541 - val_loss: 0.9111 - val_mean_absolute_error: 0.6454
# Epoch 85/100
# 16830/16830 [==============================] - 1s 81us/step - loss: 0.9124 - mean_absolute_error: 0.6548 - val_loss: 0.9095 - val_mean_absolute_error: 0.6439
# Epoch 86/100
# 16830/16830 [==============================] - 1s 82us/step - loss: 0.8968 - mean_absolute_error: 0.6476 - val_loss: 0.9063 - val_mean_absolute_error: 0.6442
# Epoch 87/100
# 16830/16830 [==============================] - 1s 83us/step - loss: 0.9041 - mean_absolute_error: 0.6489 - val_loss: 0.9048 - val_mean_absolute_error: 0.6417
# Epoch 88/100
# 16830/16830 [==============================] - 1s 83us/step - loss: 0.9056 - mean_absolute_error: 0.6517 - val_loss: 0.9036 - val_mean_absolute_error: 0.6407
# Epoch 89/100
# 16830/16830 [==============================] - 1s 82us/step - loss: 0.8938 - mean_absolute_error: 0.6444 - val_loss: 0.9003 - val_mean_absolute_error: 0.6405
# Epoch 90/100
# 16830/16830 [==============================] - 1s 82us/step - loss: 0.8955 - mean_absolute_error: 0.6441 - val_loss: 0.8976 - val_mean_absolute_error: 0.6395
# Epoch 91/100
# 16830/16830 [==============================] - 2s 92us/step - loss: 0.9167 - mean_absolute_error: 0.6564 - val_loss: 0.8975 - val_mean_absolute_error: 0.6384
# Epoch 92/100
# 16830/16830 [==============================] - 1s 84us/step - loss: 0.8872 - mean_absolute_error: 0.6420 - val_loss: 0.8939 - val_mean_absolute_error: 0.6366
# Epoch 93/100
# 16830/16830 [==============================] - 1s 83us/step - loss: 0.8957 - mean_absolute_error: 0.6448 - val_loss: 0.8921 - val_mean_absolute_error: 0.6359
# Epoch 94/100
# 16830/16830 [==============================] - 1s 84us/step - loss: 0.8971 - mean_absolute_error: 0.6473 - val_loss: 0.8939 - val_mean_absolute_error: 0.6349
# Epoch 95/100
# 16830/16830 [==============================] - 1s 84us/step - loss: 0.8938 - mean_absolute_error: 0.6437 - val_loss: 0.8886 - val_mean_absolute_error: 0.6337
# Epoch 96/100
# 16830/16830 [==============================] - 1s 83us/step - loss: 0.8787 - mean_absolute_error: 0.6374 - val_loss: 0.8868 - val_mean_absolute_error: 0.6332
# Epoch 97/100
# 16830/16830 [==============================] - 1s 83us/step - loss: 0.8870 - mean_absolute_error: 0.6399 - val_loss: 0.8866 - val_mean_absolute_error: 0.6321
# Epoch 98/100
# 16830/16830 [==============================] - 1s 84us/step - loss: 0.8828 - mean_absolute_error: 0.6393 - val_loss: 0.8839 - val_mean_absolute_error: 0.6317
# Epoch 99/100
# 16830/16830 [==============================] - 1s 84us/step - loss: 0.8808 - mean_absolute_error: 0.6364 - val_loss: 0.8818 - val_mean_absolute_error: 0.6308
# Epoch 100/100
# 16830/16830 [==============================] - 1s 85us/step - loss: 0.8800 - mean_absolute_error: 0.6369 - val_loss: 0.8803 - val_mean_absolute_error: 0.6302

# %%
f, (ax1, ax2) = plt.subplots(2,1, figsize=(15,10))
ax1.plot(history.history['loss'], lw=2, label='train')
ax1.plot(history.history['val_loss'], lw=2, label='val')
ax1.set_title('Loss: MSE')
ax1.legend()
ax2.plot(history.history['mean_absolute_error'], label='train')
ax2.plot(history.history['val_mean_absolute_error'], label='val')
ax2.set_title('Metric: MAE')
ax2.legend()

# %% [markdown]
# ## Paso 3: Prediction

# %%
x_test = features_test_set.values.astype('float32')
x_test_lstm = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
x_test_lstm.shape
# Out:
# (5260, 5, 1)

# %%
predicted = model.predict(x_test_lstm)

# %%
df_prediction = test_set.copy()
df_prediction.head()
# Out:
#                       f_0   f_1   f_2   f_3   f_4   f_5  target_h1
# target_date
# 2006-05-26 20:00:00  5.30  5.19  5.24  5.27  4.45  3.92       4.19
# 2006-05-26 21:00:00  5.19  5.24  5.27  4.45  3.92  4.19       4.60
# 2006-05-26 22:00:00  5.24  5.27  4.45  3.92  4.19  4.60       5.34
# 2006-05-26 23:00:00  5.27  4.45  3.92  4.19  4.60  5.34       4.70
# 2006-05-27 00:00:00  4.45  3.92  4.19  4.60  5.34  4.70       3.00

# %%
df_prediction = test_set.copy()
df_prediction.head()
# Out:
#                       f_0   f_1   f_2   f_3   f_4   f_5  target_h1
# target_date
# 2006-05-26 20:00:00  5.30  5.19  5.24  5.27  4.45  3.92       4.19
# 2006-05-26 21:00:00  5.19  5.24  5.27  4.45  3.92  4.19       4.60
# 2006-05-26 22:00:00  5.24  5.27  4.45  3.92  4.19  4.60       5.34
# 2006-05-26 23:00:00  5.27  4.45  3.92  4.19  4.60  5.34       4.70
# 2006-05-27 00:00:00  4.45  3.92  4.19  4.60  5.34  4.70       3.00

# %%
df_prediction['target_predicted'] = predicted
df_prediction.head()
# Out:
#                       f_0   f_1   f_2   f_3   f_4   f_5  target_h1  \
# target_date
# 2006-05-26 20:00:00  5.30  5.19  5.24  5.27  4.45  3.92       4.19
# 2006-05-26 21:00:00  5.19  5.24  5.27  4.45  3.92  4.19       4.60
# 2006-05-26 22:00:00  5.24  5.27  4.45  3.92  4.19  4.60       5.34
# 2006-05-26 23:00:00  5.27  4.45  3.92  4.19  4.60  5.34       4.70
# 2006-05-27 00:00:00  4.45  3.92  4.19  4.60  5.34  4.70       3.00
#
#                      target_predicted
# target_date
# 2006-05-26 20:00:00          3.903308
# 2006-05-26 21:00:00          4.263915
# 2006-05-26 22:00:00          4.707568
# 2006-05-26 23:00:00          5.565814
# 2006-05-27 00:00:00          4.610158

# %%
# save test dataframe (df_prediction)
filename =  os.path.join(directory, experiment_name)
df_prediction.to_csv('{0}.csv'.format(filename))

# %%
#title='LSTM-10-unit_hidden-5'
title='LSTM-10-unit-hidden-10-5-3'

f, ax = plt.subplots(1,1,figsize=(10,10))
x_min = df_prediction.target_h1.min() 
x_max = df_prediction.target_h1.max()
y_min = df_prediction.target_predicted.min()
y_max = df_prediction.target_predicted.max()
ax.set_title(title)
# line
ax.set_xlim(x_min+1, x_max+1)
ax.set_ylim(x_min+1, x_max+1)
ax.plot((x_min, x_max), (x_min, x_max), lw=3, c='r')
# scatter
df_prediction.plot(ax=ax,
                   x='target_h1',
                   y='target_predicted',
                   kind='scatter',
                  )

# %%
df_prediction.iloc[:,-2:].plot(figsize=(15,5))

# %%
 df_prediction.head()
# Out:
#                       f_0   f_1   f_2   f_3   f_4   f_5  target_h1  \
# target_date
# 2006-05-26 20:00:00  5.30  5.19  5.24  5.27  4.45  3.92       4.19
# 2006-05-26 21:00:00  5.19  5.24  5.27  4.45  3.92  4.19       4.60
# 2006-05-26 22:00:00  5.24  5.27  4.45  3.92  4.19  4.60       5.34
# 2006-05-26 23:00:00  5.27  4.45  3.92  4.19  4.60  5.34       4.70
# 2006-05-27 00:00:00  4.45  3.92  4.19  4.60  5.34  4.70       3.00
#
#                      target_predicted
# target_date
# 2006-05-26 20:00:00          3.812248
# 2006-05-26 21:00:00          4.229212
# 2006-05-26 22:00:00          4.651007
# 2006-05-26 23:00:00          5.476356
# 2006-05-27 00:00:00          4.478142

# %%
df_prediction['mse_h1'] = np.power(df_prediction.target_h1 -
                                   df_prediction.target_predicted, 2)

# %%
df_prediction['mae_h1'] = np.abs(df_prediction.target_h1 - 
                                 df_prediction.target_predicted)

# %%
# write on disk
df_prediction.head()
# Out:
#                       f_0   f_1   f_2   f_3   f_4   f_5  target_h1  \
# target_date
# 2006-05-26 20:00:00  5.30  5.19  5.24  5.27  4.45  3.92       4.19
# 2006-05-26 21:00:00  5.19  5.24  5.27  4.45  3.92  4.19       4.60
# 2006-05-26 22:00:00  5.24  5.27  4.45  3.92  4.19  4.60       5.34
# 2006-05-26 23:00:00  5.27  4.45  3.92  4.19  4.60  5.34       4.70
# 2006-05-27 00:00:00  4.45  3.92  4.19  4.60  5.34  4.70       3.00
#
#                      target_predicted    mse_h1    mae_h1
# target_date
# 2006-05-26 20:00:00          3.812248  0.142696  0.377752
# 2006-05-26 21:00:00          4.229212  0.137484  0.370788
# 2006-05-26 22:00:00          4.651007  0.474711  0.688993
# 2006-05-26 23:00:00          5.476356  0.602728  0.776356
# 2006-05-27 00:00:00          4.478142  2.184903  1.478142

# %%
test_mse = df_prediction.mse_h1.sum() / len(df_prediction.mse_h1)
test_mse
# Out:
# 0.8684822857193597

# %%
test_mae = df_prediction.mae_h1.sum() / len(df_prediction.mae_h1)
test_mae
# Out:
# 0.5835365459175618
